# %%
t1 = 2,3,5,6,8
print(type(t1),t1)
# Out:
# <class 'tuple'> (2, 3, 5, 6, 8)

# %%
t1, t2 = 2,3,4,56
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-396623ee68a8> in <module>()
# ----> 1 t1, t2 = 2,3,4,56
#
# ValueError: too many values to unpack (expected 2)

# %%
t1 = (10)
print(type(t1), t1)
# Out:
# <class 'int'> 10

# %%
t1 = (10,)
print(type(t1), t1)
# Out:
# <class 'tuple'> (10,)

# %%
l = [1,2,3,4,5,4,5,6,7]
t1 = tuple(l)
t1
# Out:
# (1, 2, 3, 4, 5, 4, 5, 6, 7)

# %%
print(t1[0])
print(t1[1:3])
print(t1[1:8:2])
print(t1[-1])
print(t1[12])
# Out:
# 1
# (2, 3)
# (2, 4, 4, 6)
# 7
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-331221fdf11a> in <module>()
#       3 print(t1[1:8:2])
#       4 print(t1[-1])
# ----> 5 print(t1[12])
#
# IndexError: tuple index out of range

# %%
t1[-1] = 12222
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-9a6977184511> in <module>()
# ----> 1 t1[-1] = 12222
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1=(10,20,30)
t2=('a','v','b')
t3=t1+t2
print(t3)
# Out:
# (10, 20, 30, 'a', 'v', 'b')

# %%
t1*5
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30, 10, 20, 30, 10, 20, 30)

# %%
t2 = t1*5
len(t1), t2.count(20)
# Out:
# (3, 5)

# %%
a = 'aaa'
b = 9.34
c = 999
d = [1,2,3,4]

t1 = a,b,c,d
t1
# Out:
# ('aaa', 9.34, 999, [1, 2, 3, 4])

# %%
x,y,z,k = t1
x
# Out:
# 'aaa'

# %%
t1 = (0,43,53,566,344,34)

for t in t1:
  print(t)
# Out:
# 0
# 43
# 53
# 566
# 344
# 34
