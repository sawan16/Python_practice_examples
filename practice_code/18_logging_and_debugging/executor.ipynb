# %%
import logging
logging.basicConfig(filename='log.txt',level=logging.WARNING)
print("Logging started.............")
logging.debug("debugging")
logging.info("Info")
logging.warning("Warning..")
logging.error("Error...")
logging.critical("Critical....")
# Out:
# Logging started.............

# %%
lg = open('log.txt')
lg.readlines()
# Out:
# ['WARNING:root:Warning..\n',
#  'ERROR:root:Error...\n',
#  'CRITICAL:root:Critical....\n']

# %%
import logging
logging.basicConfig(filename='log.txt',level=logging.INFO)
print("Logging started.............")
logging.debug("debugging")
logging.info("Info")
logging.warning("Warning..")
logging.error("Error...")
logging.critical("Critical....")
# Out:
# Logging started.............

# %%
lg = open('log.txt')
lg.readlines()
# Out:
# ['WARNING:root:Warning..\n',
#  'ERROR:root:Error...\n',
#  'CRITICAL:root:Critical....\n',
#  'WARNING:root:Warning..\n',
#  'ERROR:root:Error...\n',
#  'CRITICAL:root:Critical....\n']

# %%
import logging
logging.basicConfig(filename='log.txt',level=logging.INFO)
logging.info("program started...")
try:
 x=int(input())
 y=int(input())
 print(x/y)
except ZeroDivisionError as msg:
 print('y must not be zero..')
 logging.exception(msg)
except ValueError as msg:
 print('value not in right form')
 logging.exception(msg)
logging.info('Completed.......')
# Out:
# 6
# 9
# 0.6666666666666666

# %%
lg = open('log.txt')
lg.readlines()
# Out:
# ['WARNING:root:Warning..\n',
#  'ERROR:root:Error...\n',
#  'CRITICAL:root:Critical....\n',
#  'WARNING:root:Warning..\n',
#  'ERROR:root:Error...\n',
#  'CRITICAL:root:Critical....\n',
#  'ERROR:root:division by zero\n',
#  'Traceback (most recent call last):\n',
#  '  File "<ipython-input-7-01a2efb238ab>", line 7, in <module>\n',
#  '    print(x/y)\n',
#  'ZeroDivisionError: division by zero\n']

# %%
def get_sum(a,b):
  return a+b   #a*b

assert get_sum(12,3) == 15
assert get_sum(1,2) == 3
