# %%
a=131
b=2.5
print('a+b=',a+b)
print('a-b=',a-b)
print('a*b=',a*b)
print('a/b=',a/b)
print('a//b=',a//b) #
print('a%b=',a%b)
print('a**b=',a**b)
# Out:
# a+b= 133.5
# a-b= 128.5
# a*b= 327.5
# a/b= 52.4
# a//b= 52.0
# a%b= 1.0
# a**b= 196416.62264431696

# %%
print('data'+'4')
print('data'*4)
print('data'+4)
# Out:
# data4
# datadatadatadata
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a398ad47dc59> in <module>()
#       1 print('data'+'4')
#       2 print('data'*4)
# ----> 3 print('data'+4)
#
# TypeError: must be str, not int

# %%
a=10
b=20
print("a > b is ",a>b)
print("a == b is ",a == b)
print("a >= b is ",a>=b)
print("a < b is ",a<b)
print("a <= b is ",a<=b)
# Out:
# a > b is  False
# a == b is  False
# a >= b is  False
# a < b is  True
# a <= b is  True

# %%
a='sawan'
b='rai'
print("a > b is ",a>b)

print("a >= b is ",a>=b)
print("a < b is ",a<b)
print("a <= b is ",a<=b)
# Out:
# a > b is  True
# a == b is  False
# a >= b is  True
# a < b is  False
# a <= b is  False

# %%
print(str(10) > 'a') # 10>'a'
# Out:
# False

# %%
10<20<30<4 #10<20<30<40
# Out:
# False

# %%
10 == 'data'
# Out:
# False

# %%
10 != 'data'
# Out:
# True

# %%
False == False
# Out:
# True

# %%
print(True and True)
print(False and True)
print(False and False)
print(True and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(False or True)
print(False or False)
print(True or False)
# Out:
# True
# True
# False
# True

# %%
not 1
# Out:
# False

# %%
not -23423
# Out:
# False

# %%
not 0
# Out:
# True

# %%
not ''
# Out:
# True

# %%
'a' and 'b'
# Out:
# 'b'

# %%
'' and 'b'
# Out:
# ''

# %%
'a' or 'b'
# Out:
# 'a'

# %%
'' or 'b'
# Out:
# 'b'

# %%
5 & 1   # 5.1 & 4.1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-0cd50a65a2e7> in <module>()
# ----> 1 5 & 1.1
#
# TypeError: unsupported operand type(s) for &: 'int' and 'float'

# %%
5 | 1
# Out:
# 5

# %%
5 ^ 4 # XOR
# Out:
# 1

# %%
~ 1
# Out:
# -2

# %%
~ -4
# Out:
# 3

# %%
16 >> 2
# Out:
# 4

# %%
4 << 2
# Out:
# 16

# %%
30 if 3 > 0 else 40
# Out:
# 30

# %%
d1 = 10
d2 = 10

d1 is d2, d1 is not d2
# Out:
# (True, False)

# %%
list1=["one","two","three"]
list2=["one","two","three"]
print(id(list1))
print(id(list2))
print(list1 is list2)
print(list1 is not list2)
print(list1 == list2)
# Out:
# 140118806186888
# 140118806186824
# False
# True
# True

# %%
l1 = [1,2,3,4,5]
55 in l1, 55 not in l1
# Out:
# (False, True)
