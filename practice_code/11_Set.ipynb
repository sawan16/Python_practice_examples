# %%
set1 = {1,1,1,1,2,3,4,4,4,4,5,5,5,5,5}
print(type(set1), set1)
# Out:
# <class 'set'> {1, 2, 3, 4, 5}

# %%
set1 = {}
type(set1)
# Out:
# dict

# %%
set1 = set()
type(set1)
# Out:
# set

# %%
set1 = {44,5,23,65}
print(set1)
set1.add('a')
print(set1)
# Out:
# {65, 44, 5, 23}
# {65, 5, 44, 23, 'a'}

# %%
set1 = {1,2,3,4,5}
set1.update([12,12,33,1])
print(set1)
# Out:
# {1, 2, 3, 4, 5, 33, 12}

# %%
set1 = {1,2,3,4,5}
set1.add([12,12,33,1])
print(set1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6ccba1db87d2> in <module>()
#       1 set1 = {1,2,3,4,5}
# ----> 2 set1.add([12,12,33,1])
#       3 print(set1)
#
# TypeError: unhashable type: 'list'

# %%
set1 = {1,2,3,4,5}
print(set1.pop())
print(set1)
# Out:
# 1
# {2, 3, 4, 5}

# %%
set1 = {1,2,3,4,5}
print(set1.remove(3))
print(set1)
set1.remove(44)
# Out:
# None
# {1, 2, 4, 5}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-52034fa9b6ca> in <module>()
#       2 print(set1.remove(3))
#       3 print(set1)
# ----> 4 set1.remove(44)
#
# KeyError: 44

# %%
set1 = {1,2,3,4,5}
set1.discard(23)

# %%
set1 = {1,2,3,4,5}
set1.clear()
set1
# Out:
# set()

# %%
set1 = {'A', 'B', 'C', 'D', 'E'}
set2 = {'X', 'Z', 'C', 'D', 'Y'}

print('union:', set1|set2)
print('intersaction:', set1 & set2 )
print('differance:', set1-set2)
print('symatric diff:', set1 ^ set2)
# Out:
# union: {'B', 'Y', 'C', 'Z', 'A', 'D', 'E', 'X'}
# intersaction: {'D', 'C'}
# differance: {'B', 'E', 'A'}
# symatric diff: {'Y', 'X', 'B', 'A', 'E', 'Z'}

# %%
set1 = {'A', 'B', 'C', 'D', 'E'}
'J' in set1
# Out:
# False

# %%
set1 = {'A', 'B', 'C', 'D', 'E'}
set1[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-9f6c78fc040e> in <module>()
#       1 set1 = {'A', 'B', 'C', 'D', 'E'}
# ----> 2 set1[3]
#
# TypeError: 'set' object does not support indexing
