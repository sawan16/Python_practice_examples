# %%
print('line1---------')
10/0
print('line2---------')
# Out:
# line1---------
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-3d83af9aac8a> in <module>()
#       1 print('line1---------')
# ----> 2 10/0
#       3 print('line2---------')
#
# ZeroDivisionError: division by zero

# %%
try:
  print('line1---------')
  10/0
  print('line2---------')
except ZeroDivisionError:
  print('Exception handled.....')
# Out:
# line1---------
# Exception handled.....

# %%
try:
  print('line1---------')
  10/0
  
except ZeroDivisionError:
  print('Exception handled.....')
print('line2---------')
# Out:
# line1---------
# Exception handled.....
# line2---------

# %%
try:
  a = int(input('enter first value..'))
  b = int(input('enter second value..'))
  print('a/b:',a/b)
except ZeroDivisionError:
  print('second value must not be zero')
# Out:
# enter first value..wer
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-3c9368e05a49> in <module>()
#       1 try:
# ----> 2   a = int(input('enter first value..'))
#       3   b = int(input('enter second value..'))
#       4   print('a/b:',a/b)
#       5 except ZeroDivisionError:
#
# ValueError: invalid literal for int() with base 10: 'wer'

# %%
try:
  a = int(input('enter first value..'))
  b = int(input('enter second value..'))
  print('a/b:',a/b)
except ZeroDivisionError:
  print('second value must not be zero')
except ValueError:
  print('value must be in correct form')
# Out:
# enter first value..e
# value must be in correct form

# %%
try:
  a = int(input('enter first value..'))
  b = int(input('enter second value..'))
  print('a/b:',a/b)
except Exception:
  print('exception handled.....')
except ZeroDivisionError:
  print('second value must not be zero')
except ValueError:
  print('value must be in correct form')
# Out:
# enter first value..we
# exception handled.....

# %%
try:
  a = int(input('enter first value..'))
  b = int(input('enter second value..'))
  print('a/b:',a/b)
except ValueError:
  print('value must be in correct form')
except:
  print('default block...')
# Out:
# enter first value..3
# enter second value..0
# default block...

# %%
try:
  a = int(input('enter first value..'))
  b = int(input('enter second value..'))
  print('a/b:',a/b)
except:
  print('default block...')
except ValueError:
  print('value must be in correct form')
# Out:
#   File "<ipython-input-9-fac24106f925>", line 4
#     print('a/b:',a/b)
#                   ^
# SyntaxError: default 'except:' must be last

# %%
try:
  a = int(input('enter first value..'))
  b = int(input('enter second value..'))
  print('a/b:',a/b)
except (ValueError, ZeroDivisionError) as err:
  print(err)
# Out:
# enter first value..10
# enter second value..0
# division by zero

# %%
print('line1-------')
try:
  print('line2-------')
  10/int(input())
  print('line3-------')
except:
  print('line4.--except block')
finally:
  print('line5-------finally')
print('line6-------end')
# Out:
# line1-------
# line2-------
# 1
# line3-------
# line5-------finally
# line6-------end

# %%
print('line1-------')
try:
  print('line2-------')
  10/int(input())
  print('line3-------')
finally:
  print('line5-------finally')
print('line6-------end')
# Out:
# line1-------
# line2-------
# 0
# line5-------finally
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-c653cee78aa0> in <module>()
#       2 try:
#       3   print('line2-------')
# ----> 4   10/int(input())
#       5   print('line3-------')
#       6 finally:
#
# ZeroDivisionError: division by zero

# %%
print('line1-------')
try:
  print('line2-------')
  10/int(input())
  print('line3-------')
  try:
    print('inner- line1-------')
    10/int(input())
    print('inner line2-------')
  except ZeroDivisionError:
    print('inner line3--except block')
  finally:
    print('inner line4-------finally')
  print('inner line5-------end inner')
except:
  print('line4.--except block')
finally:
  print('line5-------finally')
print('line6-------end')
# Out:
# line1-------
# line2-------
# 9
# line3-------
# inner- line1-------
# sd
# inner line4-------finally
# line4.--except block
# line5-------finally
# line6-------end

# %%
try:
  10/int(input())
except:
  print('except block')
else:
  print('else block')
finally:
  print('finally')
# Out:
# 0
# except block
# finally

# %%
try:
  10/int(input())
else:
  print('else block')
finally:
  print('finally')
# Out:
#   File "<ipython-input-20-44500c5fdce3>", line 3
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
#Custom exception....
