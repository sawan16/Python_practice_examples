# %%
data = 90

if data < 100:
  print('data is less than 100')
# Out:
# data is less than 100

# %%
data = 90

if data < 100:
  print('data is less than 100')
else:
  print('data is greater than 100')
# Out:
# data is less than 100

# %%
name = input('enter name')

if len(name) == 0:
  print('name len is zero')
elif len(name) > 0 and len(name) < 10:
  print('name len is within range')
else:
  print('name len is more than 10 chars')
# Out:
# enter nameaaaaaaaaaaaaaaaaaaaa
# name len is more than 10 chars
