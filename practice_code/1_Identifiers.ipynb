# %%
data = 90

# %%
da$ta = 67
# Out:
#   File "<ipython-input-2-19adf6a11add>", line 1
#     da$ta = 67
#       ^
# SyntaxError: invalid syntax

# %%
data123 = 90

# %%
123data = 45
# Out:
#   File "<ipython-input-4-5a6451bf9c24>", line 1
#     123data = 45
#           ^
# SyntaxError: invalid syntax

# %%
_data = 8

# %%
__data__ = 9

# %%
my_data = 20

# %%
data-vesion = 6
# Out:
#   File "<ipython-input-8-5cbbd7b779d1>", line 1
#     data-vesion = 6
#                    ^
# SyntaxError: can't assign to operator

# %%
attr = 23
ATTR = 244

attr, ATTR
# Out:
# (23, 244)

# %%
if = 45
# Out:
#   File "<ipython-input-10-400e21b93243>", line 1
#     if = 45
#        ^
# SyntaxError: invalid syntax

# %%
int = 234
int
# Out:
# 234

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']
