# %%
data1 = 8
type(data1)
# Out:
# int

# %%
data1 = 8.0
type(data1)
# Out:
# float

# %%
data1 = 'data'
type(data1)
# Out:
# str

# %%
data1 = True
type(data1)
# Out:
# bool

# %%
data1 = 9 + 3j
type(data1)
# Out:
# complex

# %%
data1 = 20
data2 = 20

id(data1), id(data2)
# Out:
# (10915104, 10915104)

# %%
data1 = 20
data2 = 20.0

id(data1), id(data2)
# Out:
# (10915104, 140515949810408)

# %%
data1 = 0B0100 # 0b111
data1
# Out:
# 4

# %%
data1 = 0o11  # 0O323
data1
# Out:
# 9

# %%
data1 = 0XAA
data1
# Out:
# 170

# %%
bin(20), oct(20), hex(20)
# Out:
# ('0b10100', '0o24', '0x14')

# %%
data1 = 0o111 + 6j
data1
# Out:
# (73+6j)

# %%
data1 = 5.4
type(data1)
# Out:
# float

# %%
data1 = 5e3
type(data1), data1
# Out:
# (float, 5000.0)

# %%
data1 = ob1111.00
data1
# Out:
#   File "<ipython-input-18-fb1bbfeb14cd>", line 1
#     data1 = ob1111.00
#                     ^
# SyntaxError: invalid syntax

# %%
data1 = 2 + 4j
data2 = 4 + 5j
data1 + data2
# Out:
# (6+9j)

# %%
data1 =  0o111 + 0b11j
# Out:
#   File "<ipython-input-13-35e5217a50c8>", line 1
#     data1 =  0o111 + 0b11j
#                          ^
# SyntaxError: invalid syntax

# %%
data1 = 34 + 67j
data1.real, data1.imag
# Out:
# (34.0, 67.0)

# %%
a = 45 > 89
a
# Out:
# False

# %%
False + True
# Out:
# 1

# %%
False + False
# Out:
# 0

# %%
bool(-3243)
# Out:
# True

# %%
bool(0 + 1j)
# Out:
# True

# %%
bool( 0 + 0j)
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %%
bool('')
# Out:
# False

# %%
bool('d')
# Out:
# True

# %%
data = 'sawan'
data[:], data[1], data[:3], data[2:], data[1:3]
# Out:
# ('sawan', 'a', 'saw', 'wan', 'aw')

# %%
data*7
# Out:
# 'sawansawansawansawansawansawansawan'

# %%
data + 23
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-7d0b4f59601c> in <module>()
# ----> 1 data + 23
#
# TypeError: must be str, not int

# %%
data + '34'
# Out:
# 'sawan34'

# %%
int(56.56), int(True), int('4')
# Out:
# (56, 1, 4)

# %%
int(9 + 4j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-c7386f3a3beb> in <module>()
# ----> 1 int(9 + 4j)
#
# TypeError: can't convert complex to int

# %%
int('six')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-196d25768c28> in <module>()
# ----> 1 int('six')
#
# ValueError: invalid literal for int() with base 10: 'six'

# %%
int('4.4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-5f18153aa99d> in <module>()
# ----> 1 int('4.4')
#
# ValueError: invalid literal for int() with base 10: '4.4'

# %%
int(0b111111)
# Out:
# 63

# %%
float(45), float(True), float('6')
# Out:
# (45.0, 1.0, 6.0)

# %%
float('56.5')
# Out:
# 56.5

# %%
complex(4), complex('4'), complex(5.5)
# Out:
# ((4+0j), (4+0j), (5.5+0j))

# %%
complex('3 + 8j')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-175d33cd96ca> in <module>()
# ----> 1 complex('3 + 8j')
#
# ValueError: complex() arg is a malformed string

# %%
complex(4,5)
# Out:
# (4+5j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
d1 = 34
d2 = 34
d1 is d2, id(d1), id(d2)
# Out:
# (True, 10915552, 10915552)

# %%
d1 = 34 + 6j
d2 = 34 + 6j
d1 is d2, id(d1), id(d2)
# Out:
# (False, 140515809428592, 140515809428848)

# %%
d1 = 34.6
d2 = 34.6
d1 is d2, id(d1), id(d2)
# Out:
# (False, 140515810499080, 140515810499152)

# %%
d1 = True
d2 = True
d1 is d2, id(d1), id(d2)
# Out:
# (True, 10302848, 10302848)

# %%
d1 = 'a'
d2 = 'a'
d1 is d2, id(d1), id(d2)
# Out:
# (True, 140516384162568, 140516384162568)
