# %%
ch = 'd'
type(ch)
# Out:
# str

# %%
data = """ multipline 
data
"""
data
# Out:
# ' multipline \ndata\n'

# %%
s='This is ' single quote symbol'
s='This is \' single quote symbol'
s="This is ' single quote symbol"
s='This is " double quotes symbol'
s='The "Python Notes" by 'durga' is very helpful'
s="The "Python Notes" by 'durga' is very helpful"
s='The \"Python Notes\" by \'durga\' is very helpful'
s='''The "Python Notes" by 'durga' is very helpful'''

# %%
data = 'sawan'
print(data[0])
print(data[4])
print(data[-1])
print(data[-5])
print(data[40])
# Out:
# s
# n
# n
# s
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-1c801885d3c5> in <module>()
#       4 print(data[-1])
#       5 print(data[-5])
# ----> 6 print(data[40])
#
# IndexError: string index out of range

# %%
data = 'C and Python are two important languages.'
print('data[:]=',data[:])
print('data[1:4]=','>'+data[1:4]+'<')
print('data[1:]=','>'+data[1:]+'<')
print('data[1:15:2]=','>'+data[1:15:2]+'<')
print('data[-1:-10]=','>'+data[-1:-10]+'<')
print('data[-1:-10:-1]=','>'+data[-1:-10:-1]+'<')
print('data[::-1]=','>'+data[::-1]+'<')
# Out:
# data[:]= C and Python are two important languages.
# data[1:4]= > an<
# data[1:]= > and Python are two important languages.<
# data[1:15:2]= > n yhna<
# data[-1:-10]= ><
# data[-1:-10:-1]= >.segaugna<
# data[::-1]= >.segaugnal tnatropmi owt era nohtyP dna C<

# %%
print('data' +  'data2')
print('data'*4)
# Out:
# datadata2
# datadatadatadata

# %%
data = 'C and Python are two important languages.'
len(data)
# Out:
# 41

# %%
data = 'C and Python are two important languages.'
print('Python' in data)
print('Java' in data)
# Out:
# True
# False

# %%
data1 = 'Sawan'
data2 = 'Rai'
print(data1 == data2)
print(data1 > data2)
print(data1 < data2)
# Out:
# False
# True
# False

# %%
data = '      my main motive is to learn     python          '
print('>'+data.lstrip()+'<')
print('>'+data.rstrip()+'<')
print('>'+data.strip()+'<')
# Out:
# >my main motive is to learn     python          <
# >      my main motive is to learn     python<
# >my main motive is to learn     python<

# %%
data = 'C and Python are two important languages. P'
print(data.find('P'))
print(data.find('J'))

print(data.rfind('P'))
print(data.rfind('J'))
# Out:
# 6
# -1
# 42
# -1

# %%
data = 'C and Python are two important languages. P'
print(data.index('P'))
print(data.index('J'))  #rindex
# Out:
# 6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-65a3efafc32b> in <module>()
#       1 data = 'C and Python are two important languages. P'
#       2 print(data.index('P'))
# ----> 3 print(data.index('J'))
#
# ValueError: substring not found

# %%
data = 'C and Python are two important languages. P'
print(data.find('P', 10, 20))
# Out:
# -1

# %%
s="abcabcabcabcadda"
print(s.count('a'))
print(s.count('ab'))
print(s.count('a',3,7))
# Out:
# 6
# 4
# 2

# %%
data = 'C and Python are two important languages.'
print(data.replace('Python', 'Java'))
# Out:
# C and Java are two important languages.

# %%
data = 'C and Python are two important languages.'
print(data.replace('Python', 'Java'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-8ec54b865b8c> in <module>()
#       1 data = 'C and Python are two important languages.'
# ----> 2 print(data.replace('Python', 'Java', 10,20))
#
# TypeError: replace() takes at most 3 arguments (4 given)

# %%
data = 'C and Python are two important languages.'
print(data.split())
print(data.split('a'))
# Out:
# ['C', 'and', 'Python', 'are', 'two', 'important', 'languages.']
# ['C ', 'nd Python ', 're two import', 'nt l', 'ngu', 'ges.']

# %%
data = ['C', 'and', 'Python', 'are', 'two', 'important', 'languages.']
'-'.join(data)
# Out:
# 'C-and-Python-are-two-important-languages.'

# %%
s='C and Python are two important languages.'
print(s.upper())
print(s.lower())
print(s.swapcase())
print(s.title())
print(s.capitalize())
# Out:
# C AND PYTHON ARE TWO IMPORTANT LANGUAGES.
# c and python are two important languages.
# c AND pYTHON ARE TWO IMPORTANT LANGUAGES.
# C And Python Are Two Important Languages.
# C and python are two important languages.

# %%
data = 'C and Python are two important languages.'
data.startswith('C'), data.endswith('C')
# Out:
# (True, False)

# %%
print('sawanrai'.isalnum()) #True
print('sawanrai777'.isalpha()) #False
print('sawan'.isalpha()) #True
print('rai'.isdigit()) #False
print('1008'.isdigit()) #True
print('data'.islower()) #True
print('AAAAAA'.islower()) #False
print('aaaaaaaaaaa'.islower()) #True
print('Learning python is Easy'.istitle()) #False
print('Learning Python Is Easy'.istitle()) #True
print(' '.isspace()) #True
# Out:
# True
# False
# True
# False
# True
# True
# False
# True
# False
# True
# True

# %%
print("The float number is: {:8.3f}".format(123.4567))
print("The float number is: {:08.3f}".format(123.4567))
print("The float number is: {:08.3f}".format(123.45))
print("The float number is: {:08.3f}".format(786786123.45))
# Out:
# The float number is:  123.457
# The float number is: 0123.457
# The float number is: 0123.450
# The float number is: 786786123.450

# %%
print("Binary Form:{0:b}".format(153))
print("Octal Form:{0:o}".format(153))
print("Hexa decimal Form:{0:x}".format(154))
print("Hexa decimal Form:{0:X}".format(154))
# Out:
# Binary Form:10011001
# Octal Form:231
# Hexa decimal Form:9a
# Hexa decimal Form:9A

# %%
print("{:5d}".format(12))
print("{:<5d}".format(12))
print("{:<05d}".format(12))
print("{:>5d}".format(12))
print("{:>05d}".format(12))
print("{:^5d}".format(12))
print("{:=5d}".format(-12))
print("{:^10.3f}".format(12.23456))
print("{:=6.3f}".format(-12.23456))
# Out:
#    12
# 12
# 12000
#    12
# 00012
#  12
# -  12
#   12.235
# -12.235

# %%
print("{:.3}".format("sawanrai"))
print("{:5.3}".format("sawanrai"))
print("{:>5.3}".format("sawanrai"))
print(">"+"{:^6.4}".format("sawanrai")+"<")
print("{:*^5.3}".format("sawanrai"))
# Out:
# saw
# saw
#   saw
# > sawa <
# *saw*

# %%
person={'age':40,'name':'Ajay'}
print("{p[name]}'s age is: {p[age]}".format(p=person))
# Out:
# Ajay's age is: 40

# %%
string="{:{fill}{align}{width}}"
print(string.format('cat',fill='*',align='^',width=5))
print(string.format('cat',fill='*',align='^',width=6))
print(string.format('cat',fill='*',align='<',width=6))
print(string.format('cat',fill='*',align='>',width=8))
# Out:
# *cat*
# *cat**
# cat***
# *****cat
