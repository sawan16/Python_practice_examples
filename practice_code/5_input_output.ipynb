# %%
x=input("Enter First Number:")
y=input("Enter Second Number:")
i = int(x)
j = int(y)
print("The Sum:",i+j)
# Out:
# Enter First Number:2
# Enter Second Number:3
# The Sum: 5

# %%
a,b= [int(x) for x in input("Enter 2 numbers :").split()]
print("Product is :", a**b)
# Out:
# Enter 2 numbers :3 4
# Product is : 81

# %%
print('test\tpython\nfor me.')
# Out:
# test	python
# for me.

# %%
print('test'+'data')
print('my name','data')
# Out:
# testdata
# my name data

# %%
d1,d2,d3 = 1,2,3
print('d1 d2 d3 are',d1,d2,d3)
# Out:
# d1 d2 d3 are 1 2 3

# %%
d1,d2,d3 = 1,2,3
print('d1 d2 d3 are',d1,d2,d3,sep=',')
# Out:
# d1 d2 d3 are,1,2,3

# %%
d1,d2,d3 = 1,2,3
print('d1 d2 d3 are',d1,d2,d3,end='\n')
# Out:
# d1 d2 d3 are 1 2 3

# %%
a=10
b=20
c=30
print("a value is %i" %a)
print("b value is %d and c value is %d" %(b,c))
# Out:
# a value is 10
# b value is 20 and c value is 30

# %%
name="Sawan"
roll_no=100012
password="wwwsa"
print("Hello {0} your roll no is {1} and Your password {2}".format(name, roll_no, password))
print("Hello {x} your roll no is {y} and Your password {z}".format(x=name,y=roll_no,z=password))
# Out:
# Hello Sawan your roll no is 100012 and Your password wwwsa
# Hello Sawan your roll no is 100012 and Your password wwwsa
