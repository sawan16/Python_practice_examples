# %%
d1 = {}
d2 = dict()

print(type(d1), type(d2))
# Out:
# <class 'dict'> <class 'dict'>

# %%
d1 = {'A':1000, 'B': 4000, 'C': 2000}
print(d1)
d1['Z'] = 50
print(d1)
# Out:
# {'A': 1000, 'B': 4000, 'C': 2000}
# {'A': 1000, 'B': 4000, 'C': 2000, 'Z': 50}

# %%
d1 = {'A':1000, 'B': 4000, 'C': 2000}
print(d1)
d1['Z'] = 50
print(d1)
d1['A'] = 30
print(d1)
# Out:
# {'A': 1000, 'B': 4000, 'C': 2000}
# {'A': 1000, 'B': 4000, 'C': 2000, 'Z': 50}
# {'A': 30, 'B': 4000, 'C': 2000, 'Z': 50}

# %%
print(d1['A'])
print(d1['VV'])
# Out:
# 1000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-a3c8d3017cfe> in <module>()
#       1 print(d1['A'])
# ----> 2 print(d1['VV'])
#
# KeyError: 'VV'

# %%
d1 = {'A':1000, 'B': 4000, 'C': 2000}
print(d1)
del d1['A']
print(d1)

del d1['A']
# Out:
# {'A': 1000, 'B': 4000, 'C': 2000}
# {'B': 4000, 'C': 2000}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-5e7b8e50d3c7> in <module>()
#       4 print(d1)
#       5
# ----> 6 del d1['A']
#
# KeyError: 'A'

# %%
d1 = {'A':1000, 'B': 4000, 'C': 2000}
d1.clear()
d1
# Out:
# {}

# %%
d1 = {'A':1000, 'B': 4000, 'C': 2000}
print(d1.get('A'))
# Out:
# 1000

# %%
d1 = {'A':1000, 'B': 4000, 'C': 2000}
print(d1.get('AA'))
# Out:
# None

# %%
d1 = {'A':1000, 'B': 4000, 'C': 2000}
print(d1.get('AA','default value'))
# Out:
# default value

# %%
d1 = {'A':1000, 'B': 4000, 'C': 2000}
print(d1.pop('A'))
print(d1)
# Out:
# 1000
# {'B': 4000, 'C': 2000}

# %%
for i in range(10):
  d1 = {'A':1000, 'B': 4000, 'C': 2000}
  print(d1.popitem())
# Out:
# ('C', 2000)
# ('C', 2000)
# ('C', 2000)
# ('C', 2000)
# ('C', 2000)
# ('C', 2000)
# ('C', 2000)
# ('C', 2000)
# ('C', 2000)
# ('C', 2000)

# %%
d1 = {}
print(d1.popitem())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-712dd903d40b> in <module>()
#       1 d1 = {}
# ----> 2 print(d1.popitem())
#
# KeyError: 'popitem(): dictionary is empty'

# %%
d1 = {'A':1000, 'B': 4000, 'C': 2000}
print(d1.keys())
print(d1.values())
# Out:
# dict_keys(['A', 'B', 'C'])
# dict_values([1000, 4000, 2000])

# %%
d1 = {'A':1000, 'B': 4000, 'C': 2000}
for k,v in d1.items():
  print(k,v)
# Out:
# A 1000
# B 4000
# C 2000

# %%
d1 = {'A':1000, 'B': 4000, 'C': 2000}
d2 = d1

d2['DD'] = 90

print(d1)
# Out:
# {'A': 1000, 'B': 4000, 'C': 2000, 'DD': 90}

# %%
d1 = {'A':1000, 'B': 4000, 'C': 2000}
d2 = d1.copy()

d2['DD'] = 90

print(d1)
# Out:
# {'A': 1000, 'B': 4000, 'C': 2000}

# %%
squares={x:x*x for x in range(1,6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
