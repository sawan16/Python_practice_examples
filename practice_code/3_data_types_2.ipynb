# %%
data = bytes([1,2,3,4,5])
print(data)
for i in data:
  print(i)
# Out:
# b'\x01\x02\x03\x04\x05'
# 1
# 2
# 3
# 4
# 5

# %%
data = bytes([1,2,3,4,-25])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b1352200e53b> in <module>()
# ----> 1 data = bytes([1,2,3,4,-25])
#
# ValueError: bytes must be in range(0, 256)

# %%
data = bytes([1,2,3,4,5])
data[2] = 9
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-24817acb5237> in <module>()
#       1 data = bytes([1,2,3,4,5])
# ----> 2 data[2] = 9
#
# TypeError: 'bytes' object does not support item assignment

# %%
data = bytearray([1,2,3,4,5])
print(data)
for i in data:
  print(i)
data[3] = 99
for i in data:
  print(i)
# Out:
# bytearray(b'\x01\x02\x03\x04\x05')
# 1
# 2
# 3
# 4
# 5
# 1
# 2
# 3
# 99
# 5

# %%
data = bytearray([1,2,3,4,256])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c8b13e9266e7> in <module>()
# ----> 1 data = bytearray([1,2,3,4,256])
#
# ValueError: byte must be in range(0, 256)

# %%
list1 = [5,6,4,73,6]
for i in list1:
  print(i)
# Out:
# 5
# 6
# 4
# 73
# 6

# %%
list1 = [5,6,4,73,6]
list1[2] = True
list1.append('data')
list1.remove(5)
list1
# Out:
# [6, True, 73, 6, 'data']

# %%
list1*3
# Out:
# [6, True, 73, 6, 'data', 6, True, 73, 6, 'data', 6, True, 73, 6, 'data']

# %%
tuple1 = (1,2,3,4,5)
tuple1[4]
# Out:
# 5

# %%
tuple1[4] = 43
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-a8226835a1b8> in <module>()
# ----> 1 tuple1[4] = 43
#
# TypeError: 'tuple' object does not support item assignment

# %%
rng = range(5)
rng, rng[0]
# Out:
# (range(0, 5), 0)

# %%
rng[1] = 3344
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-e6ef379f6456> in <module>()
# ----> 1 rng[1] = 3344
#
# TypeError: 'range' object does not support item assignment

# %%
for i in rng:
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(2,10,3):
  print(i)
# Out:
# 2
# 5
# 8

# %%
for i in range(10,1,-2):
  print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
st = {1,232,232,4,4,4,4,9}
st
# Out:
# {1, 4, 9, 232}

# %%
st.add(34)
st
# Out:
# {1, 4, 9, 34, 232}

# %%
st.remove(4)

# %%
fst = frozenset({1,2,2,2,3,546,7})
fst
# Out:
# frozenset({1, 2, 3, 7, 546})

# %%
fst.add(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-7c9f73ed2c93> in <module>()
# ----> 1 fst.add(4)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
fst.remove(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-99ac3a42c137> in <module>()
# ----> 1 fst.remove(3)
#
# AttributeError: 'frozenset' object has no attribute 'remove'

# %%
dict1 = {1:'a',2:'d'}
dict1[45] ='data'
dict1
# Out:
# {1: 'a', 2: 'd', 45: 'data'}

# %%
dict1.keys(), dict1.values()
# Out:
# (dict_keys([1, 2, 45]), dict_values(['a', 'd', 'data']))

# %%
None
